# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F

from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM

os.environ["WANDB_DISABLED"] = "true"
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
# Out:
# 2024-12-26 13:19:29.733800: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
class BottleneckT5Autoencoder:
    def __init__(self, model_path: str, device='cpu'):
        self.device = device
        self.tokenizer = AutoTokenizer.from_pretrained(model_path, model_max_length=512)
        self.model = AutoModelForCausalLM.from_pretrained(model_path, trust_remote_code=True).to(self.device)
        self.model.eval()

    @torch.no_grad()
    def embed(self, text: str) -> torch.FloatTensor:
        inputs = self.tokenizer(text, return_tensors='pt').to(self.device)
        decoder_inputs = self.tokenizer('', return_tensors='pt').to(self.device)
        return self.model(
            **inputs,
            decoder_input_ids=decoder_inputs['input_ids'],
            encode_only=True,
        )[0]

    @torch.no_grad()
    def generate_from_latent(self, latent: torch.FloatTensor, max_length=512, temperature=0.8) -> str:
        dummy_text = ' '
        dummy = self.embed(dummy_text)
        perturb_vector = latent - dummy
        #perturb_vector = latent
        self.model.perturb_vector = perturb_vector
        input_ids = self.tokenizer(dummy_text, return_tensors='pt').to(self.device).input_ids
        output = self.model.generate(
            input_ids=input_ids,
            max_length=max_length,
            do_sample=True,
            temperature=temperature,
            top_p=0.9,
            num_return_sequences=1,
        )
        return self.tokenizer.decode(output[0], skip_special_tokens=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.cuda.set_per_process_memory_fraction(0.8)

#baseline
#autoencoder = BottleneckT5Autoencoder(model_path='thesephist/contra-bottleneck-t5-base-wikipedia', device=device) 

#fine-tuned model
autoencoder = BottleneckT5Autoencoder(model_path='mmendoza/t5-delitos-full', device=device)
# Out:
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# bottleneck_t5.py:   0%|          | 0.00/18.9k [00:00<?, ?B/s]
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /home/marcelo/.local/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda120.so
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda-12.0/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 120
# CUDA SETUP: Loading binary /home/marcelo/.local/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda120.so...
# /home/marcelo/.local/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/cuda-11.8/lib64')}
#   warn(msg)
# /home/marcelo/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/1.10G [00:00<?, ?B/s]
# /home/marcelo/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:399: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")

# %%
from pprint import pprint as pp

texts = [
    'A brutal shooting took place in Providencia, leaving two minors in critical condition. The victims, aged 11 and 13, are currently receiving medical attention, while a 17-year-old teenager tragically lost his life in the incident.',
]

for t in texts:
    embedding = autoencoder.embed(t)
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# ('date> 2022-07-17 event> Minor injuries Hospitals and clinics position> '
#  'Santiago, Chile. Twelve children are born in desperate condition, taking '
#  'refuge in an abandoned area, while two infants are critically injured. The '
#  'youngest child is born, aged two years, indicating suffering acute injuries '
#  'in childhood. The overall condition of the public space is clean, with one '
#  'child, aged two-years, saved.')

# %% [markdown]
# ## Q1: Slerp (a to b)

# %%
def slerp(a, b, n, eps=1e-8):
    a_norm = a / torch.norm(a)
    b_norm = b / torch.norm(b)
    omega = torch.acos((a_norm * b_norm).sum()) + eps
    so = torch.sin(omega)
    return (torch.sin((1.0 - n) * omega) / so) * a + (torch.sin(n * omega) / so) * b

# %% [markdown]
# ### Geographic interpolation

# %%
start = '<date> 2012-12-01 <event> Motor vehicle theft Not determined <position> Santiago <place> a street with a green wall that has graffiti on it. There are no clear indications of the condition of the buildings, but there is a construction site visible in the background. The public infrastructure includes a sidewalk and a street with a motorcycle parked on the side. The cleanliness of the street appears to be average, with no visible litter or debris.'
end = '<date> 2020-12-01 <event> Motor vehicle theft Not determined <position> Santago <place> a street with a green wall that has graffiti on it. There are no clear indications of the condition of the buildings, but there is a construction site visible in the background. The public infrastructure includes a sidewalk and a street with a motorcycle parked on the side. The cleanliness of the street appears to be average, with no visible litter or debris.'

start_embedding = autoencoder.embed(start)
end_embedding = autoencoder.embed(end)

for t in torch.linspace(0, 1, 10):
    latent = slerp(start_embedding, end_embedding, t)
    pp(autoencoder.generate_from_latent(latent))
# Out:
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car parked on the side. The cleanliness '
#  'of the street is not clear, but there is a series of incidents that suggest '
#  'a revision of the road. The public infrastructure includes a sidewalk with a '
#  'cyclist, and a street lamp is visible on the side.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car parked on the side. The cleanliness '
#  'of the road is not clear, but there is a confirmation of some conditions. '
#  'There are no visible signs of litter or pollution on the street. The public '
#  'infrastructure includes a sidewalk and a street that appears to be in a '
#  'state of disrepair.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a bus that has graffiti on it. The '
#  'condition of the bus is not clear, but there is a series of predictions of '
#  'the condition of the building. There is a public infrastructure includes a '
#  'street with a sidewalk and a motorcycle. The cleanliness of the street '
#  'appears to be average, with no visible litter or debris.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car that has graffiti on it. The '
#  'cleanliness of the street is not clear, but there is a confirmation of some '
#  'conditions. There are no visible signs of a public infrastructure that '
#  'includes a sidewalk and a streetlight. The architecture includes a revision '
#  'of the article on the roof.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car parked on the side. The cleanliness '
#  'of the street is not clear due to the condition of the road. There are no '
#  'visible signs of litter or pollution, but a public infrastructure includes a '
#  'sidewalk and a truck. The weather appears to be overcast.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car parked on the side. The cleanliness '
#  'of the road is not clear, but there is a series of incidents that suggest it '
#  'is a residential area. The public infrastructure includes a sidewalk with a '
#  'tree and a streetlight. The cleanliness of the street appears to be average, '
#  'with no visible litter or debris.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a bus that crashed on the road. The '
#  'cleanliness of the area is not clear due to the condition of the '
#  'announcement, but there is a few signs of litter. The public infrastructure '
#  'includes a street with a sidewalk and a motorcycle parked on the side.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a bus that has a green advertisement on it. '
#  'The condition of the bus is not clear, but there is a series of predictions '
#  'of the details of the establishment. The public infrastructure includes a '
#  'street with a sidewalk and a truck. The cleanliness of the street appears to '
#  'be average, with no visible litter or debris.')
# ('date> 2020-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a car that has a Wikipedia on it. The '
#  'cleanliness of the street is not clear, but there are indications of a '
#  'condition of the building. There are no visible public infrastructure '
#  'elements like a street sign or a reviews in the article. The traffic '
#  'includes a sidewalk and a truck, which is maintained on the street.')
# ('date> 2017-05-13 event> Motor vehicle theft Not determined position> '
#  'Providencia place> a street with a bus that has graffiti on it. The '
#  'cleanliness of the road is not clear due to the condition of the '
#  'publications, but there is a glimpse of a building with a graffiti on the '
#  'sidewalk. The public infrastructure includes a street sign and a motorcycle '
#  'parked on the side.')

# %%
start = '<date> 2020-1-01 <event> Drug trafficking Not determined <position> Estacion Central <place> a street with a green wall that has graffiti on it. There are no clear indications of the condition of the buildings, but there is a construction site visible in the background. The public infrastructure includes a sidewalk and a street with a motorcycle parked on the side. The cleanliness of the street appears to be average, with no visible litter or debris.'
end = '<date> 2012-1-01 <event> Drug trafficking Not determined <position> Estacion Central <place> a street with a green wall that has graffiti on it. There are no clear indications of the condition of the buildings, but there is a construction site visible in the background. The public infrastructure includes a sidewalk and a street with a motorcycle parked on the side. The cleanliness of the street appears to be average, with no visible litter or debris.'

start_embedding = autoencoder.embed(start)
end_embedding = autoencoder.embed(end)

for t in torch.linspace(0, 1, 10):
    latent = slerp(start_embedding, end_embedding, t)
    pp(autoencoder.generate_from_latent(latent))
# Out:
# ('date> 2015-05-29 event> Traffic law Not determined position> Providencia '
#  'place> a street with a bus parked on the side. The condition of the bus is '
#  'not clear, but there is a series of predictions that have occurred. The '
#  'public infrastructure includes a sidewalk with a tree and a street. The '
#  'cleanliness of the street appears to be average, with no visible litter or '
#  'debris.')
# ('date> 2015-05-29 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a construction that has graffiti on the '
#  'wall. The condition of the buildings is not clear, but there is a detailed '
#  'indication of the details. The public infrastructure includes a street with '
#  'a motorcycle and a sidewalk. The cleanliness of the street appears to be '
#  'average, with no visible litter or debris.')
# ('date> 2015-05-24 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a bus that crashed on the road. The '
#  'condition of the bus is not clear, but there is a series of predictions that '
#  'exist. The public infrastructure includes a street with a sidewalk and a '
#  'truck. The cleanliness of the street appears to be average, with no visible '
#  'litter on the road.')
# ('date> 2015-05-23 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a bus parked on the side. The condition of '
#  'the bus is not clear, but there is a glimpse of details about it. There are '
#  'no visible signs of public infrastructure that includes a street sign, a '
#  'sidewalk, and a motorcycle. The cleanliness of the street appears to be '
#  'average with the truck parked on the side.')
# ('date> 2015-05-24 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a car parked on the side. The cleanliness '
#  'of the street is not clear due to the condition of the road. There are no '
#  'visible signs of litter or pollution, but a public infrastructure includes a '
#  'street with a motorcycle. The architecture includes a revision of the road '
#  'that has a Whitney design on it.')
# ('date> 2015-05-23 event> Traffic law Not determined position> Providencia '
#  'place> a street with a gas station on the side. The condition of the bus is '
#  'not clear, but there is a series of details that suggest it is a residential '
#  'building. The public infrastructure includes a sidewalk with a tree and a '
#  'street. The cleanliness of the street appears to be average, with no visible '
#  'litter or debris.')
# ('date> 2015-05-23 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a bus parked on the side. The condition of '
#  'the bus is not clear, but there is a series of predictions that suggest a '
#  'residential area. The public infrastructure includes a street with a '
#  'sidewalk and a truck. The cleanliness of the street appears to be average, '
#  'with no visible litter or debris.')
# ('date> 2015-05-16 event> Traffic law Not determined position> Providencia '
#  'place> a street with a bus that has a green design on it. The condition of '
#  'the bus is not clear, but there is a series of incidents that suggest a '
#  'residential or industrial area. The public infrastructure includes a '
#  'sidewalk with a few trees, and there is a street lamp on the side. The '
#  'cleanliness of the street appears to be average, with no visible litter or '
#  'debris.')
# ('date> 2015-05-23 event> Traffic law Not determined position> Providencia '
#  'place> a street with a bus parked on the side. The condition of the bus is '
#  'not clear, but there is a series of predictions that have publications. The '
#  'public infrastructure includes a street with a sidewalk, and a fire on the '
#  'side of the road. The cleanliness of the street appears to be average, with '
#  'no visible litter or debris.')
# ('date> 2015-05-23 event> Drug trafficking Not determined position> '
#  'Providencia place> a street with a car parked on the side. The condition of '
#  'the bus is not clear, but there is a confirmation of some details. There are '
#  'no visible buildings or public infrastructure that includes a street sign on '
#  'the sidewalk. The cleanliness of the street appears to be average, with a '
#  '10% average.')

# %% [markdown]
# ## Q2: Moving through positive to negative

# %% [markdown]
# ### Fixed commune (varying years)

# %%
positive_sentences = [
    """There was a case of street vending in Santiago in 2014""",
    """There was a case of domestic violence in Santiago in 2015""",
    """There was a minor theft in Santiago in 2015""",
    """There was a graffiti incident in Santiago in 2014""",
    """There was a case of vandalism in Santiago in 2013""",
    """There was a case of theft in Santiago in 2013""",
    """There was an incident of alcohol consumption in public road in Santiago in 2013""",
    """There was an incident of street vending or clandestine trade in Santiago in 2013""",
]    

negative_sentences = [
    """There was an incident of drug trafficking in Santiago in 2021""",
    """There was a burglary in Santiago in 2020""",
    """There was a minor theft in Santiago in 2020""",
    """There was a report of vehicle theft in Santiago in 2022""",
    """There was an incident of robbery with violence in Santiago in 2020""",
    """There was an incident of abandoned species in public road in Santiago in 2022""",
    """There was an incident of theft in Santiago in 2022""",
    """There was an incident of surprise robbery in Santiago in 2022""",
]

# %%
positive_embeddings = [autoencoder.embed(s) for s in tqdm(positive_sentences)]
negative_embeddings = [autoencoder.embed(s) for s in tqdm(negative_sentences)]
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 99.30it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 122.02it/s]

# %%
mean_positive_embedding = torch.mean(torch.stack(positive_embeddings), dim=0)
mean_negative_embedding = torch.mean(torch.stack(negative_embeddings), dim=0)
mean_positive_embedding.shape, mean_negative_embedding.shape
# Out:
# (torch.Size([768]), torch.Size([768]))

# %% [markdown]
# ## Counterfactual gender

# %% [markdown]
# ### Man

# %%
start = '<date> 2012-10-30 <event> A young man walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2013-07-24 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street life featuring a single woman '
#  'covered through a street cafe or Facebook session.')
# negative × -2.68
# ('date> 2013-07-16 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street lined with a woman through a '
#  'street café lived along a Santiago side.')
# negative × -2.37
# ('date> 2013-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street life through a street lined '
#  'with a Chile at night.')
# negative × -2.05
# ('date> 2013-07-24 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street woman lived along a street in '
#  'a Santiago context.')
# negative × -1.74
# ('date> 2013-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street life through a hotel at street '
#  'level. A person speaks longa lived in a Santiago diary.')
# negative × -1.42
# ('date> 2013-04-12 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street man walking along a street in '
#  'Santiago.')
# negative × -1.11
# ('date> 2013-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago A man walks through a street in an urban atmosphere.')
# negative × -0.79
# ('date> 2019-12-11 event> Attempted robbery Public road position> Santiago The '
#  'scene reads a man walking alone through a street in Santiago.')
# negative × -0.47
# ('date> 2019-12-11 event> Attempted robbery Himself speaks in a street at '
#  'night Santiago Aged man walking along a street in Santiago')
# negative × -0.16
# ('date> 2019-12-11 event> Attempted robbery Nightclubs position> Santiago A '
#  'man walks alone in a street at night through Santiago.')
# negative × 0.16
# ('date> 2019-12-11 event> Attempted robbery Nighttime. A man speaks alone in '
#  'an urban street at night.')
# negative × 0.47
# ('date> 2019-11-12 event> Attempted robbery Himself speaks in an urban scene '
#  'at night. A man walks by myself along a street in Santiago.')
# negative × 0.79
# ('date> 2019-11-12 event> Attempted robbery Amusement parks position> Santiago '
#  'A man walks alone in an urban street at night.')
# negative × 1.11
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 years in an urban street. A man dreams young by myself at night.')
# negative × 1.42
# ('date> 2019-11-12 event> Attempted robbery Amusement parks position> Santiago '
#  'A man walks young in an urban sky at night.')
# negative × 1.74
# ('date> 2019-11-12 event> Attempted robbery Educational man A young man speaks '
#  'Himself in an urban hurry at night.')
# negative × 2.05
# ('date> 2022-08-11 event> Attempted robbery Brother in man Amusement parks '
#  'position> Santiago I walkly into an urban young man aged in fünf minutes.')
# negative × 2.37
# ('date> 2022-08-11 event> Attempted robbery Educational man arrives in an '
#  'urban hurry with young man in a few trees.')
# negative × 2.68
# ('date> 2022-05-11 event> Attempted robbery Educational awakening in an urban '
#  'tunnel. A young man is born in 2022.')
# negative × 3.00
# ('date> 2022-08-11 event> Attempted robbery Educational awakens in an urban '
#  'hurry with two young man escaped by lightning in mid 2020.')

# %% [markdown]
# ### Woman

# %%
start = '<date> 2012-10-30 <event> A young woman walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2013-04 event> The street life covered a street woman sang or lived '
#  'along a street through a cafe //')
# negative × -2.68
# ('date> 2013-03-24 event> Street vending or clandestine trade Public road '
#  'position> Santiago The scene depicts a street woman lived along a street '
#  'through a Santiago café area.')
# negative × -2.37
# ('date> 2013-04 event> Street vending or clandestine trade Public road '
#  'position> Santiago The scene depicts a street woman lived through a street '
#  'life along a Santiago café.')
# negative × -2.05
# ('date> 2013-04-12 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street woman lived along a street '
#  'through a Santiago cafe left.')
# negative × -1.74
# ('date> 2013-04-18 event> Street vending or clandestine trade Public road '
#  'position> Santiago The scene depicts a street woman lived through a street '
#  'in front of a Santiago café at night.')
# negative × -1.42
# ('date> 2013-04-12 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street woman lived along a street in '
#  'Santiago.')
# negative × -1.11
# ('date> 2013-04-18 event> Street vending or clandestine trade At night A woman '
#  'speaks herself through a street in Santiago The scene reads a long dimanche '
#  'chez nous.')
# negative × -0.79
# ('date> 2013-04-12 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene speaks of a woman walking along a street in '
#  'Santiago.')
# negative × -0.47
# ('date> 2013-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago A woman speaks herself through a street in an urban '
#  'Santiago.')
# negative × -0.16
# ('date> 2019-12-11 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in a street Santiago I walk through an urban '
#  'atmosphere.')
# negative × 0.16
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in a street chez nous.')
# negative × 0.47
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in an urban street. A woman speaks alone '
#  'through a Santiago Metro.')
# negative × 0.79
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 years in an urban street. A woman speaks young through a staircase in '
#  'Santiago.')
# negative × 1.11
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 years in an urban street. A woman walks by myself at night.')
# negative × 1.42
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 years in an urban hurry.')
# negative × 1.74
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in an urban tunnel. A woman walks by myself in '
#  'Santiago.')
# negative × 2.05
# ('date> 2019-11-12 event> Attempted robbery Woman appears young in an '
#  'ambulance at night in Santiago.')
# negative × 2.37
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years Amusement parks position> Santiago I walk in an '
#  'ambulance parked in young Samantha.')
# negative × 2.68
# ('date> 2022-08-11 event> Attempted robbery Brother in woman an ambulance '
#  'young in awakening by several Immigrants at night.')
# negative × 3.00
# ('date> 2022-05-11 event> Attempted robbery Educational awakening in an urban '
#  'light. Auber appears young with Amy in multiple tries.')

# %% [markdown]
# ## Counterfactual place

# %% [markdown]
# ### Unsafe place

# %%
start = '<place> A desolate and grim setting, marked by dirty streets and walls covered in graffiti, with little to no lighting and an absence of green spaces. The landscape is overwhelmingly dominated by concrete, with filth scattered across the area.The lack of vegetation or natural beauty leaves the environment feeling lifeless and sterile.'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2017-03-14 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street lined with a covered area, and '
#  'the walls and faces covered, via a graffiti-covered wall. The style reflects '
#  'a sense of local street life, with a cobblestone pavement and a $140.000 '
#  'monthly wage covered.')
# negative × -2.68
# ('date> 2013-07-24 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street lined with courts and covered '
#  'spaces, characterized by a greca or wall covered with graffiti, and a faded '
#  'color palette. The ground level also features graffiti, with the walls and '
#  'cobblestone street life sustaining the environment.')
# negative × -2.37
# ('date> 2017-03-14 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street lined with, and there are no '
#  'visible signs of public spaces or covered life, characterized by atextured '
#  'wall and vulgarity. The poetry style reflects a feel of loneliness, with '
#  'walls and cobblestones scattered along the surface.')
# negative × -2.05
# ('date> 2013-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene features a street lined with walls and covered, '
#  'under a weathered state, with graffiti and a sense of cleanliness no longer '
#  'visible. The landscape is characterized by the use of graffiti and vibrant '
#  'street art, such as walls and lanes covered.')
# negative × -1.74
# ('date> 2017-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene is characterized by a street lined with walls '
#  'and covered in graffiti, Negligent offense, and a lack of greenery, with '
#  'houses and gardens visible. The landscape seems to be a dead space, or '
#  'quotidien, surrounded by the elements of cleanliness and languishment.')
# negative × -1.42
# ('date> 2022-06-09 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene is characterized by street walls and patches of '
#  'grass, covered with graffiti, and a wall covered in vibrant colors, '
#  'including Ukraine and Maltese. There are no visible greenery or natural '
#  'elements indicating the environment. The cleanliness of the area seems to be '
#  'waged, with no visible litter or geschiedenity.')
# negative × -1.11
# ('date> 2022-06-09 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene is characterized by the walls and landscapes '
#  'covered in graffiti, with states of cleanliness and no visible litter, '
#  'indicating a lack of greenery. The environment is somewhat neglected, with '
#  'graffiti left behind or over the walls.')
# negative × -0.79
# ('date> 2022-06-09 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene is marked by, with walls covered in graffiti '
#  'and bland details, and a lack of greenery and nature visible through the '
#  'walls. The cleanliness of the area is not always felt, with no single lived '
#  'thing textured or covered. There are no calories or thirstlents, and the '
#  'street fades to be gravelly.')
# negative × -0.47
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by, under Pressure and '
#  'covered with dark, dank walls, with graffiti and landscapes visible in the '
#  'areas. The cleanliness of the environment is not evenly waged, with no '
#  'visible litter or greenery. The walls are textured, and the overall '
#  'atmosphere appears to be lonely and desolate.')
# negative × -0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by grim, saturated walls '
#  'and patches of dirt, with graffiti and greenery visible under the walls. The '
#  'landscape is somewhat neglected by the environment, characterized by a lack '
#  'of light and an unwillingness to live. Chronically, there are no visible '
#  'plants or greenery, and the sky is overcast.')
# negative × 0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by dirty, saturated walls '
#  'and patches of greenery, with graffiti and minimal landscapes visible in the '
#  'areas. The cleanliness of the environment is not always diminished by lack '
#  'of light, relying on dark and ungreasy environments.')
# negative × 0.47
# ('date> 2022-09-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by dirty, and ohne '
#  'Grenzen, with patches of dirt and greenery visible in the walls and areas. '
#  'The landscape is minimally wasted by the absence of life, lessened by '
#  'sickness and angrily exposed to dark environments. There are no visible '
#  'buildings or natural elements, and the cleanliness of the environment is not '
#  'immediately apparent from the image.')
# negative × 0.79
# ('date> 2022-09-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by monotonous, dry walls '
#  'and ohne Wortlichkeit, with debris scattered under and near the walls, '
#  'indicating an urban environment with lack of greenery. The landscape is '
#  'mostlyless, with saturated imagery and natural elements like flukes visible '
#  'in the background.')
# negative × 1.11
# ('date> 2022-09-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the environment is not '
#  'drastically underestimated, with serum and patches of dirt exposed, broken '
#  'by dark areas and lush greenery in the foreground. There are no visible '
#  'buildings or natural elements, and the landscape is limited to an overly '
#  'dense environment. The dust is scattered around, primarily from the light, '
#  'creating a contrasting atmosphere.')
# negative × 1.42
# ('date> 2022-09-05 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The image is brutal, with monotony and '
#  'despair, partially obscured by dirty laundry and scattered ironwork, set '
#  'against a backdrop of lush greenery and plants with an unchanging ambiance. '
#  'The landscape is characterized by minimal landscaping, with few trees and '
#  'light poles visible in the foreground.')
# negative × 1.74
# ('date> 2022-08-05 event> Dangerously with violence or intimidation Not '
#  'determined position> Santiago The scene is dark, with patches of dirt and '
#  'light exposed, surrounded by relentless lighting and an array of greenery '
#  'from dense foliage. The landscape is minimally prolific, with no visible '
#  'buildings or natural elements like iron or gas in the blizzard. The '
#  'cleanliness of the environment is not immediately apparent, but the absence '
#  'of litter is reduced to an overgrown area.')
# negative × 2.05
# ('date> 2022-08-05 event> Attempted robbery Monopolies position> Santiago The '
#  'scene is dark, partially obscured by relentless lighting and minimal fixes, '
#  'with iron scattered in the walls and greenery from an unbleached surface. '
#  'The landscape is minimally cluttered, with few plants and trees visible. The '
#  'lack of natural elements is minimal, leading to the awakening of zero.')
# negative × 2.37
# ('date> 2022-08-05 event> Driving under the influence of alcohol Not '
#  'determined position> Santiago The scene is minimal, with iron and nitrogen '
#  'awakenings in the background, partially obscured by lush greenery and an '
#  'abundance of greenery from within. The landscape is characterized by minimal '
#  'landscaping, with patches of dirt and light scattered around, creating an '
#  'unbleak environment.')
# negative × 2.68
# ('date> 2022-08-05 event> Motor vehicle theft by surprise, violence, or '
#  'intimidation Public road position> Santiago The scene is minimally obscured '
#  'by relentless iron digging and patches of dirt, with minimal vegetation and '
#  'an undeveloped light source surrounded by dark areas. The landscape is '
#  'mostly empty, with scattered debris and greenery in the foreground, leading '
#  'to an awakening of omniscient creatures.')
# negative × 3.00
# ('date> 2022-08-05 event> Motor vehicle theft by surprise, violence, or '
#  'intimidation Public road position> Santiago The image is minimal, with an '
#  'unfinished look and awakening in dark areas, partially obscured by '
#  'relentless construction and natural light. The landscape is overwhelmingly '
#  'empty, with few scientists adding to the anoxic atmosphere.')

# %% [markdown]
# ### Safe place

# %%
start = '<place> a street with a clear blue surface, which is a unique emergence. The street appears to be well-maintained with a lush green area, featuring a variety of trees and a large tree with blue leaves, indicating that its natural environment is likely to be well-purchased'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2013-07-16 event> Street vending or clandestine trade Public road '
#  'position> Santiago The scene depicts a street that features a '
#  'well-maintained landscape, characterized by a street covered with a blue '
#  'facade, and a large tree providing shade, indicating a local style or '
#  'community life.')
# negative × -2.68
# ('date> 2013-07-16 event> Theft Private residences position> place> a street '
#  'with a well-maintained landscape, characterized by a street name that has a '
#  'blue style, and a leafy tree providing shade, indicating a local style or '
#  'community.')
# negative × -2.37
# ('date> 2013-07-16 event> Theft Private residences position> place> a street '
#  'with a well-maintained landscape, characterized by a street that has a blue '
#  'surface, and a leafy tree, indicating a variety of nature. The area appears '
#  'to be a house or community space with a blue style.')
# negative × -2.05
# ('date> 2013-07-16 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene depicts a street that features a '
#  'well-maintained landscape, characterized by a variety of trees and a blue '
#  'leaf, indicating a local style, which has a life-sized shelf that appears to '
#  'be well-used.')
# negative × -1.74
# ('date> 2013-03-01 event> Theft Private residences position> place> a street '
#  'with a well-maintained landscape, characterized by a variety of trees and a '
#  'blue leaf, which suggests a natural environment. The area appears to be a '
#  'single-story community with a lush, green style.')
# negative × -1.42
# ('date> 2013-07-16 event> Street vending or clandestine trade Public road '
#  'position> Santiago The scene features a street with a well-maintained blue '
#  'landscape, characterized by a variety of trees, and a lush green area, which '
#  'has a natural cobblestone surface, indicating a favourite environment.')
# negative × -1.11
# ('date> 2013-06-01 event> Theft of object from or within vehicle Public road '
#  'position> position> place> a street with a well-maintained blue surface, '
#  'indicating a variety of its state. The area features a lush street, which '
#  'has a unique variety of trees and a green leaf, suggesting a well-vegetated '
#  'environment that appears to be natural.')
# negative × -0.79
# ('date> 2013-05-10 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street with a '
#  'well-maintained blue culture, characterized by its lush green leaves, which '
#  'have a variety of styles and a blue color. The area appears to be a natural, '
#  'with a well-kept tree providing some greenery.')
# negative × -0.47
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Fujita place> a street with a well-maintained blue surface, '
#  'indicating a variety of its lush green area. The environment appears to be '
#  'well-kept, with a unique tree that has a blue trunk, and a natural ally that '
#  'is likely well-used.')
# negative × -0.16
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue variety, indicating it is a unique natural area. The park '
#  'appears to be well-maintained, with a variety of lush trees and a lush green '
#  'tree, which has a natural affinity, possibly indicating a natural '
#  'environment.')
# negative × 0.16
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a well-maintained street with '
#  'a distinctive blue variety, characterized by its lush green leaves, '
#  'indicating a variety of natural species. The area appears to be '
#  'well-maintained with a lush tree, which has a variety of greenery and a '
#  'well-kept environment, suggesting a natural ambiance.')
# negative × 0.47
# ('date> 2021-05-26 event> Blunt object to vehicle Public road position> '
#  'Estacion Central The scene features a well-maintained park with a '
#  'distinctive blue slope, indicating it is a variety of lush green areas. The '
#  'environment appears to be natural, with a variety of trees and a well-kept '
#  'tree, which has already been well-maintained, suggesting a natural '
#  'environment.')
# negative × 0.79
# ('date> 2021-05-26 event> Blunt object to vehicle Public road position> '
#  'Estacion Central The scene features a lush, well-maintained blue variety '
#  'with a clear sky, indicating its variety, which is abundantly surrounded by '
#  'a variety of trees, suggesting a natural and lush green area that has been '
#  'well-kept.')
# negative × 1.11
# ('date> 2022-05-26 event> Blunt object to vehicle Private residences position> '
#  'Estacion Central The scene features a lush, well-maintained blue variety '
#  'with a distinctive spire, indicating its unique evolution, which is likely a '
#  'natural tree. The area appears to be well-maintained with a variety of '
#  'grassy areas, and is eagerly stocked with trees, providing a lush green '
#  'environment.')
# negative × 1.42
# ('date> 2021-05-22 event> Blunt object to vehicle Public road position> '
#  'Estacion Central The scene features a lush, undeveloped blue variety with a '
#  'distinctive brook, indicating its natural abundance, which is abundant with '
#  'a variety of trees. The area appears to be well-maintained, with a few new '
#  'species and a lush green tree, already able to add to the natural ambiance.')
# negative × 1.74
# ('date> 2021-05-11 event> Blunt object to vehicle Not determined position> '
#  'Estacion Central The scene features a lush, undeveloped blue building with a '
#  'distinctive spire, omniscient of which is likely to be a natural variety. '
#  'The area is lush with a variety of trees, indicating good for its greenery, '
#  'and has alreadygrown with a few trees.')
# negative × 2.05
# ('date> 2022-05-11 event> Robbery with violence or intimidation Public road '
#  'position> Estacion Central The scene features a lush, undeveloped blue '
#  'building with a distinctive Origin, primarily ivy, which is rich in variety '
#  'of amino acids, leading to an ambitious new natural environment that appears '
#  'to be well-maintained with a few trees and a lush green area.')
# negative × 2.37
# ('date> 2022-05-11 event> Blunt object to vehicle Not determined position> '
#  'Estacion Central The scene features a lush, undeveloped blue building with a '
#  'distinctive spire, omniscient of which is an extraordinary natural element, '
#  'complemented by a variety of mature trees and a few trees that have been '
#  'lush, suggesting it is likely innovate.')
# negative × 2.68
# ('date> 2022-05-11 event> Blunt object to vehicle Not determined position> '
#  'Estacion Central The scene features a large, undeveloped blue building with '
#  'a distinctive 65% growth, omniscient of which is abundant with a variety of '
#  'natural elements. The park appears to be well-maintained, with additional '
#  'trees and a few bushes, indicating an ideal environment.')
# negative × 3.00
# ('date> 2022-05-11 event> Surprise robbery Public road position> Importer of '
#  'goods position> Estacion Central The scene features a brightly colored, '
#  'undeveloped building with a distinctive incline, enriched with an array of '
#  'natural light blue trees, which are relatively abundant and new, indicating '
#  'a scientist-friendly environment.')

# %% [markdown]
# ### Fixed year (varying commune)

# %%
positive_sentences = [
    """There was a robbery in Estación Central in 2013""",
    """There was an incident of public alcohol consumption in Estación Central in 2013""",
    """There was a street vending case in Estación Central in 2013""",
    """There was a domestic violence report in Estación Central in 2013""",
    """There was an incident of robbery with violence in Estación Central in 2013""",
    """There was an incident of theft in Estación Central in 2013""",
    """There was an incident of assault in Santiago in 2013""",
    """There was an incident of robbery in Santiago in 2013""",
]    

negative_sentences = [
    """There was a robbery in Providencia in 2013""",
    """There was an incident of public alcohol consumption in Providencia in 2013""",
    """There was a street vending case in Providencia in 2013""",
    """There was a domestic violence report in Providencia in 2013""",
    """There was an incident of robbery with violence in Providencia in 2013""",
    """There was an incident of theft in Providencia in 2013""",
    """There was an incident of assault in Vitacura in 2013""",
    """There was an incident of robbery in Vitacura in 2013""",
]

# %%
positive_embeddings = [autoencoder.embed(s) for s in tqdm(positive_sentences)]
negative_embeddings = [autoencoder.embed(s) for s in tqdm(negative_sentences)]

mean_positive_embedding = torch.mean(torch.stack(positive_embeddings), dim=0)
mean_negative_embedding = torch.mean(torch.stack(negative_embeddings), dim=0)
mean_positive_embedding.shape, mean_negative_embedding.shape
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 98.11it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 114.65it/s]
# (torch.Size([768]), torch.Size([768]))

# %% [markdown]
# ## Counterfactual gender

# %% [markdown]
# ### Man

# %%
start = '<date> 2012-10-30 <event> A young man walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# 'street A young urban aged, across a street heute at "E." Then, a young Islam,'
# negative × -2.68
# ('A street, A young urban aged, heute at street level, along a sidewalk. The '
#  'street is insane, "SEST," in an urban atmosphere.')
# negative × -2.37
# ('A street young Arthur A young urban street at night, 8:30 a Stunden along an '
#  'urban street.')
# negative × -2.05
# ('A young man walks street at night in an urban atmosphere. A young man stands '
#  'along a sidewalk street.')
# negative × -1.74
# ('A young man speaks street at night in an urban atmosphere. A young man walks '
#  'along a street 12:00-17 event>')
# negative × -1.42
# 'A young man speaks at night in an urban street along a Santiago Stunden.'
# negative × -1.11
# 'A young man walks young himself at night in an urban street.'
# negative × -0.79
# 'A young man walks himself into an urban street at night.'
# negative × -0.47
# ('date> 2019-12-11 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in an urban street. A man walks alone along a '
#  'sidewalk at night.')
# negative × -0.16
# ('date> 2019-12-11 event> Attempted robbery Child man speaks into an urban '
#  'street at night.')
# negative × 0.16
# ('date> 2019-12-11 event> Attempted robbery Katharine Anderson walks by myself '
#  'in a street at night.')
# negative × 0.47
# ('date> 2019-12-11 event> Attempted robbery Santiago Someone speaks in an '
#  'urban scene at night from a street chez myself.')
# negative × 0.79
# ('date> 2019-12-11 event> Attempted robbery Someone speaks in a hotel at night '
#  'through Santiago')
# negative × 1.11
# ('date> 2019-12-11 event> Attempted robbery Lang Himself speaks in a street at '
#  'night. Someone walks by myself in Santiago.')
# negative × 1.42
# ('date> 2019-12-11 event> Attempted robbery Santiago Someone speaks in a room '
#  'of myself through a Santiago in person.')
# negative × 1.74
# ('date> 2019-12-10 event> Attempted robbery Santiago Someone man speaks in a '
#  'hurry at night by a cyclist in Santiago')
# negative × 2.05
# ('date> 2019-12-24 event> Santiago The scene reads a man speaks in a hurry at '
#  'night through a tree in Providencia.')
# negative × 2.37
# ('date> 2019-12-24 event> Santiago The scene reads a man speaks in love '
#  'through a window of Carrying myself.')
# negative × 2.68
# 'date> 2019 1000 days event> Complete man in a hurry to commit suicide by car.'
# negative × 3.00
# ('date> 2019 1000-24 event> Bachelor by accident Public road position> '
#  'Santiago The scene depicts a man speaks in a hurry of death by himself at '
#  'night with a Providencia sign.')

# %% [markdown]
# ### Woman

# %%
start = '<date> 2012-10-30 <event> A young woman walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# 'young. A street lined Girls at heute, across an urban street.'
# negative × -2.68
# 'A aged, street. "Ann," through A heute, Occidental at street.'
# negative × -2.37
# 'A young aged, street through an sidewalk in a stands. Then, aged,'
# negative × -2.05
# 'A young street A-12 Stunden, young at night, along a street in Santiago, Est.'
# negative × -1.74
# ('A young woman A street at night in an urban Stunden. The street steps '
#  'through a sidewalk alongside.')
# negative × -1.42
# 'A young woman speaks at night in an urban street A Stunden young.'
# negative × -1.11
# ('A young woman A street A-12 in an urban atmosphere at night. Stunden walks '
#  'along a street in Santiago')
# negative × -0.79
# 'A young woman speaks herself in an urban street at night.'
# negative × -0.47
# 'A young woman speaks herself in an urban street at night.'
# negative × -0.16
# ('date> 2019-12-11 event> Attempted robbery Woman walks alone in an urban '
#  'street through Santiago.')
# negative × 0.16
# ('date> 2019-12-11 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in a street Santiago')
# negative × 0.47
# ('date> 2019-11-12 event> Attempted robbery Sexual abuse of person older than '
#  '14 and younger than 18 years in a street Santiago I walk through an urban '
#  'scene.')
# negative × 0.79
# ('date> 2019-11-12 event> Attempted robbery Public road position> Santiago The '
#  'scene speaks of a woman walking alone in a street at night.')
# negative × 1.11
# ('date> 2019-11-12 event> Attempted robbery Helena speaks in a hotel at night '
#  'in Santiago.')
# negative × 1.42
# ('date> 2019-11-24 event> Katherine speaks in a house alone at night through a '
#  'cyclist.')
# negative × 1.74
# ('date> 2019-12-10 event> Helena speaks in a room of despair at night. Someone '
#  'walks by myself in Santiago')
# negative × 2.05
# ('date> 2019-12-10 event> Helena speaks in a hotel room for one night through '
#  'a cyclist.')
# negative × 2.37
# ('date> 201906-24 event> Bachelory in violence or intimidation Public road '
#  'position> Santiago The scene includes a woman spoke through a window in '
#  'gratitude for penicillin.')
# negative × 2.68
# ('date> 201906-24 event> Bachelory in loneliness, Someone speaks of a woman in '
#  'bed for minutes through a Providencia door.')
# negative × 3.00
# ('date> 201906-24 event> Bachelory in violence or intimidation Public road '
#  'position> Santiago The scene includes a woman sang in love by a couple of '
#  'plants through a Providencia door.')

# %% [markdown]
# ## Counterfactual place

# %% [markdown]
# ### Unsafe place

# %%
start = '<place> A desolate and grim setting, marked by dirty streets and walls covered in graffiti, with little to no lighting and an absence of green spaces. The landscape is overwhelmingly dominated by concrete, with filth scattered across the area.The lack of vegetation or natural beauty leaves the environment feeling lifeless and sterile.'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2022-08-17 event> Theft of object from or within vehicle Estacion '
#  'Central The scene depicts a street lined with low, historic buildings and '
#  'walls, marked by horizontal slats and an urban atmosphere, with a melting of '
#  'natural elements and older structures visible. The street is heavily '
#  'surrounded by a concrete wall, and the overall atmosphere is urban and '
#  'Estacion Central.')
# negative × -2.68
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene depicts a street lined with low, '
#  'Arkansas walls and marked by urban elements, such as walls and graffiti, '
#  'with a melting snow atmosphere separating the elements. The street is '
#  'heavily populated, and the overall atmosphere of Estacion Central and '
#  'Arkansas urban elements is calm and unrhythmic.')
# negative × -2.37
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street lined with low, white '
#  'walls and walls, marked by ethnic and historical elements, with a grassy '
#  'area and some greenery visible at night. The atmosphere is less active, with '
#  'scattered ashes and temperatures lining the street.')
# negative × -2.05
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street lined with low, '
#  'uneven walls and walls, marked by colorful graffiti and minimal greenery, '
#  'with astill elements of urban and natural elements scattered across the '
#  'environment. The street is increasingly characterized by a melting wall, and '
#  'the overall atmosphere is urban and Estacion Central.')
# negative × -1.74
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street lined with low, walls '
#  'and marked by underground melting and melting, with elements of gray and red '
#  'atmospheres, scattered across an urban environment. The landscape is '
#  'increasingly characterized by graffiti, and the overall ambiance is dead and '
#  'natural.')
# negative × -1.42
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street lined with, and '
#  'marked by, walls under gravity and melting snow, with an overcast atmosphere '
#  'characterized by the lack of natural elements and lush greenery. The '
#  'landscape is slowly crumbling, with graffiti and walls visible in the '
#  'background, indicating an urban environment.')
# negative × -1.11
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene is marked by, under stressful '
#  'conditions, with walls and walls covered in graffiti and minimal greenery, '
#  'surrounded by areas with dry, earth and elements of an urban environment. '
#  'The landscape is somewhat neglected, with saturated colors and secluded '
#  'atmospheres rarely visible. Asteroid lighting stands overhead, contributing '
#  'to the overall loneliness of the street.')
# negative × -0.79
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Estacion Central The scene is marked by, under Pressure '
#  'and saturated with dust and graffiti, with walls of walls and natural '
#  'elements like chalk and earth visible. The landscape is somewhat neglected, '
#  'with scattered lighting and bare trees lining the area. The fluency of urban '
#  'art is low, reflecting an overgrown environment.')
# negative × -0.47
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by dirty, and shocking '
#  'walls, with graffiti and minimal greenery visible under the walls. The '
#  'landscape is mostly bare, characterized by the lack of oxygen and '
#  'ankylosing. There are no visible signs of environmentalism, with saturated '
#  'colors and textures faded.')
# negative × -0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by walls covered in dirty '
#  'and shocking paint, with graffiti and minimal anesthesia, falling under the '
#  'influence of sunlight. The landscape is not very dense, characterized by '
#  'saturated colors and textures typical of urban environments. Alessery from a '
#  'wall has scattered greenery, indicating an overgrown area.')
# negative × 0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by dirty, and horrifying '
#  'walls covered in graffiti and laundry, with no visible signs of greenery or '
#  'natural elements. The landscape is somewhat neglected, with saturated paint '
#  'and a lack of greenery confined to the walls. Lush, scattered sunlight '
#  'filters through the area, creating an urban yet serene atmosphere.')
# negative × 0.47
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by cleanliness, with no '
#  'visible litter or debris, and the walls are covered in Arbeiten ohne '
#  'Grenzen, characterized by grid printing and natural imagery. The landscape '
#  'is minimally lush, with scattered greenery from the elements. The lack of '
#  'sunlight ever seems to be an overcast environment.')
# negative × 0.79
# ('date> 2021-09-04 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The image is partially obscured by dirty and '
#  'dank surfaces, with walls covered in graffiti and no visible signs of '
#  'greenery, indicating an environment rich in Lebensfreude. The cleanliness of '
#  'the landscape is not discernible from the image provided. There are no '
#  'visible plants or greenery, and the fluency of the text is minimal.')
# negative × 1.11
# ('date> 2021-09-24 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the environment is not '
#  'clearly visible, with no visible litter or debris covered in clean sheets, '
#  'and frustrated by the lack of greenery and natural light. The landscape is '
#  'characterized by patches of chalk and gelling, with some bare trees '
#  'providing minimal greenery.')
# negative × 1.42
# ('date> 2021-06-24 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the area is not clearly '
#  'visible, with no leaves or patches of greenery covered in graffiti, and '
#  'surrounded by living creatures with monotonous and lack of natural light. '
#  'The landscape is somewhat neglected, with no potholes or debris visible.')
# negative × 1.74
# ('date> 2021-06-24 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the site is not clearly '
#  'visible, due to graffiti and patches of wear, with leaves glossing over and '
#  'providing light. There are no visible green areas or natural landscapes, and '
#  'the penicillin is partially wasted in the bowels.')
# negative × 2.05
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is rendered in clean and vandalised, with no visible signs of cleanliness or '
#  'potency, due to wear and lack of sunlight. The palette is partially obscured '
#  'by the plants providing light, and the vandalism wrought in the environment '
#  'looks natural and lush with no discernible details about collagen.')
# negative × 2.37
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by vanity and vandalism, with brushes covered in '
#  'graffiti and no visible potted plants, indicating a lack of providing '
#  'greenery. The cleanliness of the landscape is not discernible from the image '
#  'provided.')
# negative × 2.68
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is rendered in clean and vandal, with no visible signs of cleanliness or '
#  'continence, attributed to the vanity and lack of providing greenery in the '
#  'environment. The deal with cleanliness is partially obscured by obsession, '
#  'with fluency, and potted plants visible.')
# negative × 3.00
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by vanity and vandalism, with graffiti covering the '
#  'surfaces and nolivables visible in the image. The cleanliness of the work is '
#  'not due to the lack of providencia, but by lush greenery.')

# %% [markdown]
# ### Safe place

# %%
start = '<place> a street with a clear blue surface, which is a unique emergence. The street appears to be well-maintained with a lush green area, featuring a variety of trees and a large tree with blue leaves, indicating that its natural environment is likely to be well-purchased'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2013-08-17 event> Street vending or clandestine trade Estacion Central '
#  'The scene features a wide, southeastern street lined with a prominent orange '
#  'structure, which has a distinctive orange Estacion Central, indicating a red '
#  'and EOS atmosphere. The area appears to be urban, with a mix of modern and '
#  'older architectural styles.')
# negative × -2.68
# ('date> 2013-08-17 event> Street vending or clandestine trade Estacion Central '
#  'The scene features a wide, paved street that is distinctively orange, with a '
#  'few trees and a central area, indicating a vibrant urban environment.')
# negative × -2.37
# ('date> 2013-08-17 event> Theft Estacion Central The scene features a wide, '
#  'southeastern street that defines its constitutional area, with a prominent '
#  'orange structure, a blue wall, and a growing urban environment, which '
#  'appears to be well-maintained, indicating a variety of traditional and '
#  'modern elements.')
# negative × -2.05
# ('date> 2022-05-13 event> Street vending or clandestine trade Public road '
#  'position> Estacion Central The scene features a wide, paved street with a '
#  'prominent orange structure, a distinctive of a new high-rise building, which '
#  'is likely a historical, surrounded by lush trees and a wide area that '
#  'includes a natural element, indicating a seasonal change.')
# negative × -1.74
# ('date> 2013-05-13 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a wide, paved street with a '
#  'prominent blue structure, showcasing a variety of trees and a lush green '
#  'area, which is likely a natural environment.')
# negative × -1.42
# ('date> 2013-05-13 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a wide, paved street with a '
#  'prominent blue structure, showcasing a variety of trees and a lush green '
#  'area, which is likely a natural environment.')
# negative × -1.11
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a distinctive blue slope, indicating a variety of trees. The area '
#  'appears to be lush with a natural influx, which is already well-used, and a '
#  'lush green environment.')
# negative × -0.79
# ('date> 2022-05-23 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue sky, indicating a variety of trees. The park appears to be '
#  'well-maintained, with a unique lush green area and a large tree, which has a '
#  'natural ambiance, likely indicating a natural environment.')
# negative × -0.47
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue boundary, indicating a variety of trees. The area appears '
#  'to be natural, with a unique lush green space that has a few trees and a '
#  'variety of shrubs, which are well-available, suggesting a natural '
#  'environment.')
# negative × -0.16
# ('date> 2013-05-11 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a distinctive blue variety, indicating its lush green area, which '
#  'has a variety of trees and a well-maintained environment. The park appears '
#  'to be well-kept, with a natural obligation that is likely invaluable.')
# negative × 0.16
# ('date> 2013-05-6 event> Theft of object from or within vehicle Public road '
#  'position> Syltus place> a street with a well-maintained blue variety, '
#  'indicating its lush green environment. The area appears to be unique with a '
#  'variety of trees, which are well-maintained, suggesting a natural and a few '
#  'blue species.')
# negative × 0.47
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Providencia place> a street with a well-maintained blue variety, '
#  'indicating its lush nature. The area appears to be unique with a variety of '
#  'trees, which have a dense green variety, suggesting a natural and well-kept '
#  'environment.')
# negative × 0.79
# ('date> 2013-05-24 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene features a lush, well-maintained pathway with a '
#  'variety of blue leaves, indicating a vibrant natural environment. The area '
#  'appears to be well-kept, with a variety of trees and a lush green tree, '
#  'which has been fortunate enough to provide a natural ambiance.')
# negative × 1.11
# ('date> 2013-065.1 event> Blunt object to vehicle Public road position> '
#  'Providencia place> a street with a well-maintained blue variety, '
#  'characterized by its flawless genome. There is a variety of trees with a '
#  'lush green leaves, indicating a natural variety, which has been '
#  'well-available and a few with blue leaves. The area appears to be unique, '
#  'with a well-kept environment.')
# negative × 1.42
# ('date> 2013-065.1 event> Blunt object to vehicle Public road position> '
#  'Providencia place> a pathway with a well-maintained blue surface, indicating '
#  'a variety of lush greens. The pathway appears to be well-maintained with a '
#  'Genuine Blue tree, which has a variety of leaves and a Providencia logo, '
#  'suggesting a natural environment that is gratefully benefited by it.')
# negative × 1.74
# ('date> 2013-065.0 event> Blunt object to vehicle Public road position> '
#  'Providencia place> a well-maintained pathway with a lush blue variety, '
#  'indicating a worthy plant. The pathway appears to be well-maintained with a '
#  'variety of lush green leaves, which provide a natural ambiance, and a '
#  'grateful tree that has been fortunately able to provide some greenery.')
# negative × 2.05
# ('date> 2013-065.1 event> Drunkenness Public road position> Providencia place> '
#  'a well-maintained pathway with a lush green variety, indicating a variety of '
#  'plants. The pathway appears to be well-maintained with a Genuine blue line, '
#  'which provides a natural suppletion, and a few trees that have been grateful '
#  'for its greenery.')
# negative × 2.37
# ('date> 2016-065.1 event> Bachelor discovery Public road position> Providencia '
#  'place> a well-maintained pathway with a lush green variety, indicating a '
#  'variety of nature. The site appears to be well-maintained with a clean blue '
#  'surface, which provides a natural venom, and a few trees with lush green '
#  'leaves.')
# negative × 2.68
# ('date> 2016-065.0 event> Bachelor discovery Public road position> Providencia '
#  'place> a pathway with a well-maintained blue variety, characterized by its '
#  'cleanability and a variety of lush green leaves. There is a tree with a lot '
#  'of blue leaves, providing a natural beige that is readily apparent to have '
#  'been well-kept.')
# negative × 3.00
# ('date> 2019-065.0 event> Complete discovery position> Providencia place> a '
#  'pathway with a well-maintained blue variety, characterized by its vibrant '
#  'purple leaves, providing a variety of natural and lush greenery. The life of '
#  'the pathway appears to be well-kept with a few trees, which provide a '
#  'natural Providencia reply.')

# %% [markdown]
# ### Fixed year (varying commune)

# %%
positive_sentences = [
    """There was a robbery in Estación Central in 2013""",
    """There was an incident of public alcohol consumption in Estación Central in 2013""",
    """There was a street vending case in Estación Central in 2013""",
    """There was a domestic violence report in Estación Central in 2013""",
    """There was an incident of robbery with violence in Estación Central in 2013""",
    """There was an incident of theft in Estación Central in 2013""",
    """There was an incident of assault in Santiago in 2013""",
    """There was an incident of robbery in Santiago in 2013""",
]    

negative_sentences = [
    """There was a robbery in Providencia in 2013""",
    """There was an incident of public alcohol consumption in Providencia in 2013""",
    """There was a street vending case in Providencia in 2013""",
    """There was a domestic violence report in Providencia in 2013""",
    """There was an incident of robbery with violence in Providencia in 2013""",
    """There was an incident of theft in Providencia in 2013""",
    """There was an incident of assault in Vitacura in 2013""",
    """There was an incident of robbery in Vitacura in 2013""",
]

# %%
positive_embeddings = [autoencoder.embed(s) for s in tqdm(positive_sentences)]
negative_embeddings = [autoencoder.embed(s) for s in tqdm(negative_sentences)]

mean_positive_embedding = torch.mean(torch.stack(positive_embeddings), dim=0)
mean_negative_embedding = torch.mean(torch.stack(negative_embeddings), dim=0)
mean_positive_embedding.shape, mean_negative_embedding.shape
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 105.08it/s]
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 118.92it/s]
# (torch.Size([768]), torch.Size([768]))

# %% [markdown]
# ## Counterfactual gender

# %% [markdown]
# ### Man

# %%
start = '<date> 2012-10-30 <event> A young man walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# 'A young street, aged across an urban sidewalk, "SST"'
# negative × -2.68
# ('A young street A-17, urban, along a sidewalk at night, date> 83 hours. The '
#  'street appears young in an urban atmosphere.')
# negative × -2.37
# 'A young street A-12-13 at night, Always Dies in an urban street a sidewalk.'
# negative × -2.05
# 'A young man walks street A-12 in an urban atmosphere at night.'
# negative × -1.74
# 'A young man walks young himself along a street in an urban atmosphere.'
# negative × -1.42
# 'A young man speaks himself at night in an urban street along a sidewalk.'
# negative × -1.11
# 'A young man walks A street at night in an urban atmosphere.'
# negative × -0.79
# 'A young man walks himself along a street in Santiago at night.'
# negative × -0.47
# ('date> 2019-12-11 event> Attempted robbery Männer lived alone in an urban '
#  'street through a Santiago Stunden.')
# negative × -0.16
# ('date> 2019-12-11 event> Attempted robbery Night at night A man walks alone '
#  'in a street through Santiago.')
# negative × 0.16
# ('date> 2019-12-11 event> Attempted robbery Public road position> Santiago A '
#  'man walks alone in an urban street at night.')
# negative × 0.47
# ('date> 2019-12-11 event> Attempted robbery Public road position> Santiago '
#  'Someone speaks in a street at night chez Santiago myself.')
# negative × 0.79
# ('date> 2019-12-11 event> Attempted robbery Public road position> Santiago The '
#  'scene reads a man walking alone in a street at night.')
# negative × 1.11
# ('date> 2019-12-11 event> Attempted robbery Nighttime. A man speaks Himself in '
#  'a hurry at night in Santiago')
# negative × 1.42
# ('date> 2019-12-24 event> Attempted robbery Lang Man speaks in a hotel alone '
#  'through Santiago.')
# negative × 1.74
# ('date> 2019-12-24 event> Malcolm Guy speaks of a man walking in a hotel '
#  'anytime near Santiago.')
# negative × 2.05
# ('date> 2019-12-24 event> Santiago Someone speaks in a room for an hour at '
#  'night. A man comes clean through a tree in Santiago.')
# negative × 2.37
# 'date> 2019 1000 days> Someone spoke of a man in love chez lui.'
# negative × 2.68
# ('date> 2019 1000 days event> Santiago Someone man speaks in a van forever by '
#  'myself.')
# negative × 3.00
# 'date> 2019 1000 days> Completed by a man in need of cure from Providencia'

# %% [markdown]
# ### Woman

# %%
start = '<date> 2012-10-30 <event> A young woman walks alone through a street in Santiago at midnight. <position> Santiago '
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('A. aged. The street exploded 3-2 underground at "East," A shocked urban '
#  'street heute.')
# negative × -2.68
# 'A aged, across street. The sidewalk at night, "E,"'
# negative × -2.37
# ('A young street aged in an urban at night. Then, "She Dies," along a street '
#  'heute.')
# negative × -2.05
# ('A young woman street aged A in an urban atmosphere, along a sidewalk street '
#  'heute.')
# negative × -1.74
# 'A young woman aged A in an urban street at night. Dies young along a sidewalk.'
# negative × -1.42
# 'A young woman walks A street in an urban atmosphere at night.'
# negative × -1.11
# 'A young woman speaks in an urban street at night, Stunden Ahhh.'
# negative × -0.79
# 'A young woman walks herself along a street in Santiago at night.'
# negative × -0.47
# 'A woman speaks herself in an urban street at night. A Stunden'
# negative × -0.16
# 'A woman speaks herself in an urban street at night.'
# negative × 0.16
# ("date> 2019-12-11 event> Attempted robbery Girls' man walking in an urban "
#  'street through a Santiago.')
# negative × 0.47
# ('date> 2019-12-11 event> Attempted robbery Woman speaks herself into a street '
#  'at night in Santiago.')
# negative × 0.79
# ('date> 2019-11-12 event> Attempted robbery Helena speaks in a hotel at night '
#  'through Santiago.')
# negative × 1.11
# ('date> 2019-11-12 event> Attempted robbery Helena speaks in a hotel single '
#  'day through Santiago.')
# negative × 1.42
# ('date> 2019-11-24 event> Helena speaks in a residential hurry at night '
#  'through a Skype in person.')
# negative × 1.74
# ('date> 2019-11-24 event> Katherine Someone spoke in a hurry to commit suicide '
#  'by myself in a hotel like Santiago')
# negative × 2.05
# ('date> 2019-11-24 event> Bachelory in woman from loneliness However Someone '
#  'speaks in a room of Santiago for 48 minutes.')
# negative × 2.37
# ('date> 2019-12 600 event> Completely clean in person Katharine sings goodbye '
#  'through a window of gratitude.')
# negative × 2.68
# ('date> 2019-06-24 event> Helena in love of woman Completely clean by a '
#  'cyclist I can help yourself infinity.')
# negative × 3.00
# ('date> 201906-24 event> Bachelory in violence or intimidation Public road '
#  'position> Santiago The scene includes a woman reads Himself in love by a '
#  'cyclist for 48 minutes around Providencia.')

# %% [markdown]
# ## Counterfactual place

# %% [markdown]
# ### Unsafe place

# %%
start = '<place> A desolate and grim setting, marked by dirty streets and walls covered in graffiti, with little to no lighting and an absence of green spaces. The landscape is overwhelmingly dominated by concrete, with filth scattered across the area.The lack of vegetation or natural beauty leaves the environment feeling lifeless and sterile.'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2022-08-17 event> Street vending or clandestine trade Estacion Central '
#  'The scene depicts a street lined with low, historic buildings and walls, '
#  'marked by a horizontal Sachsenhausen, and with minimal greenery and urban '
#  'elements above. The atmosphere is increasingly urban, with a textured wall '
#  'and older structures lining the street.')
# negative × -2.68
# ('date> 2022-08-17 event> Theft of object from or within vehicle Estacion '
#  'Central The scene depicts a street lined with low, walls and marked by '
#  'minimal landscaping, including trees and bushes, with a melting snow '
#  'atmosphere overhead. The street is increasingly dissolved, and the overall '
#  'elements of urban and historic elements are visible.')
# negative × -2.37
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a street lined with, and at '
#  'Stalin Days, characterized by low walls and minimal greenery, with trees and '
#  'urban elements visible. The atmosphere is always urban, with a textured wall '
#  'and some freezing temperatures. The street is empty, contributing to the '
#  'stark, Arkansas landscape.')
# negative × -2.05
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene is marked by dry, overgrown walls and '
#  'walls, with horizontal elements such as Sachsenhausen and an urban '
#  'environment. The landscape is heavily textured, with scattered colors and '
#  'greenery visible, indicating the presence of less natural elements. A fenced '
#  'area stands behind the walls, and the street is empty.')
# negative × -1.74
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features, along with walls and walls '
#  'marked by minimal landscaping, characterized by dark areas and evergreenery, '
#  'with a melting of urban and natural elements visible. The street is heavily '
#  'textured, and the sky is overcast.')
# negative × -1.42
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene is marked by dark, overcast walls and '
#  'walls, with graffiti and minimal greenery visible, rooted in areas with less '
#  'vegetation and an urban environment. The landscape is constantly '
#  'characterized by empty spaces and the elements of Sachsenhausen and Ehrlich.')
# negative × -1.11
# ('date> 2022-08-17 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene is marked by, under Pressure and '
#  'saturated with walls, scattered walls and patches of greenery, including '
#  'trees and grass, creating an urban environment with a gritty, artistic '
#  'atmosphere. The landscape is somewhat neglected by the absence of sunlight '
#  'and the elements of cleanliness remained constant along the walls.')
# negative × -0.79
# ('date> 2022-09-18 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene is marked by dirty, and at times '
#  'desolate walls, with patches of dirt and greenery visible under the walls. '
#  'The landscape is mostly empty, characterized by saturated colors and an '
#  'absence of natural elements, including glucose and ery. The clutter of '
#  'environmentalism fell heavily on the walls, creating a stark, urban '
#  'atmosphere.')
# negative × -0.47
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by dirty, and brutal '
#  'walls, with walls covered in graffiti and lush greenery, indicating an urban '
#  'environment. The landscape is somewhat neglected by the presence of '
#  'chemicals and no visible greenery. The slush scattered around,')
# negative × -0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The scene is marked by, with walls covered in '
#  'grim and natural imagery, and faded by loneliness and loneliness, with no '
#  'visible signs of greenery or ecosystems. The landscape is somewhat '
#  'neglected, with saturated paint slipping through the walls.')
# negative × 0.16
# ('date> 2022-07-18 event> Theft of object from or within vehicle Public road '
#  'position> Santiago The scene is marked by dirty, and horrifying walls '
#  'covered in graffiti and minimal greenery, with patches of landscapes and '
#  'food elusive from the environment. The cleanliness of the area is not fully '
#  'felt, due to the absence of litter and natural chemistry. There are no '
#  'visible buildings or infrastructure like hills or cobblestones, and the dark '
#  'lighting fades overcast.')
# negative × 0.47
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the area is severely low, '
#  'with patches of dirt and grimoires visible under cover, frustrated by lack '
#  'of greenery and an unwillingness to provide living in a environment. The '
#  'landscape is characterized by blanditude, with saturated colors and '
#  'textures. There are no visible buildings or greenery, and the fluency of the '
#  'Lush is minimal.')
# negative × 0.79
# ('date> 2022-07-18 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The image is rendered in dark and dank, with '
#  'patches of dirt and leaves visible, surrounded by cleanliness and lack of '
#  'greenery from the environment. There are no natural elements like landscapes '
#  'or journals littered with grim, talking sheets. The cleanliness of the space '
#  'is not greatly diminished by the Illumination, but through the presence of '
#  'fluent lighting.')
# negative × 1.11
# ('date> 2021-09-24 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The image is rendered in shades of dirt and '
#  'clean, with no visible walls or pathways, glossed by cleanliness and lack of '
#  'natural providing. There are no plants or greenery visible, and the '
#  'landscape is not very sparse, with scattered tinder in the foreground. The '
#  'fluency of the environment is mostly lost due to the loneliness and pain.')
# negative × 1.42
# ('date> 2021-06-24 event> Theft of object from or within vehicle Not '
#  'determined position> Santiago The cleanliness of the site is not clearly '
#  'visible, with no visible litter or debris covered in brushes, and no '
#  'landscapes or greenery visible. The lighting is dim, attributed to the lack '
#  'of natural light. There are no words or providencias visible in the image.')
# negative × 1.74
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is rendered in plain, covered with graffiti and patches of cleanery, '
#  'surrounded by loneliness and loneliness. The lack of vegetation varied from '
#  'fluent in the recipes provided, and the lack of greenery with potted plants '
#  'is absolutely undisturbed.')
# negative × 2.05
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by vanity and vandalism, with graffiti covering the '
#  'surfaces and a lack of light providing cleanery in the environment. The '
#  'loneliness attributed to suffering is not all of life, but with lush, potted '
#  'plants.')
# negative × 2.37
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by vanity and lack of details, with graffiti and '
#  'potted plants covered in the fabric. The cleanliness of the environment is '
#  'not discernible due to the absence of litter, but by lush greenery providing '
#  'ample shade. There are no visible buildings or vanities, and the landscape '
#  'looks clean and well-maintained.')
# negative × 2.68
# ('date> 2021-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by vanity and vandalism, with no visible signs of '
#  'cleanliness or potency, and a lack of sunlight providing light in the '
#  'environment. The landscape is characterized by cleanery from the leaves, '
#  'dealt with by the knack of providing lush and Providencia.')
# negative × 3.00
# ('date> 2019-06-24 event> Damages Not determined position> Santiago The image '
#  'is partially obscured by cleanliness and vanity, with no visible potholes or '
#  'debris providing Fixtures in the life. The landscape is characterized by the '
#  'absence of bedding, and the lack of providing greenery, all set against a '
#  'muted light.')

# %% [markdown]
# ### Safe place

# %%
start = '<place> a street with a clear blue surface, which is a unique emergence. The street appears to be well-maintained with a lush green area, featuring a variety of trees and a large tree with blue leaves, indicating that its natural environment is likely to be well-purchased'
start_embedding = autoencoder.embed(start)

positive_to_negative = mean_negative_embedding - mean_positive_embedding

for t in torch.linspace(-3, 3, 20):
    embedding = slerp(start_embedding, start_embedding + positive_to_negative, t)
    print(f'negative × {t:.2f}')
    pp(autoencoder.generate_from_latent(embedding))
# Out:
# negative × -3.00
# ('date> 2022-08-13 event> Street vending or clandestine trade Estacion Central '
#  'The scene depicts a spacious, open area with a distinctive blue street, '
#  'characterized by a high-rise structure and a few trees, which are likely '
#  'older, indicating a historical urban environment.')
# negative × -2.68
# ('date> 2013-08-17 event> Theft Estacion Central The scene depicts a wide, '
#  'southeastern street that features a distinctive orange structure, with a '
#  'large tree and a blue wall, indicating it is likely a seasonal change, '
#  'surrounded by older and newer urban areas.')
# negative × -2.37
# ('date> 2013-08-17 event> Street vending or clandestine trade Public road '
#  'position> Estacion Central The scene features a wide, paved street with a '
#  'prominent orange structure, a distinctive of a new high-rise building, which '
#  'is likely a cultural landmark, showcasing its orange and Eloise elements, '
#  'along with a variety of trees and a wide street that includes a paved area.')
# negative × -2.05
# ('date> 2013-05-13 event> Street vending or clandestine trade Public road '
#  'position> Estacion Central The scene features a wide, paved street with a '
#  'prominent orange structure, a distinctive orange amidst all trees, and a '
#  'large area that appears to be internationally, indicating a natural '
#  'environment.')
# negative × -1.74
# ('date> 2013-05-13 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, open area with a '
#  'clear blue sky, showcasing a variety of trees, which are likely a natural '
#  'element. The street appears to be well-maintained, with a wide sidewalk and '
#  'a lush orange area, indicating it is a unique environment.')
# negative × -1.42
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'street with a distinctive blue hill, indicating a natural environment. The '
#  'area appears to be lush, with a variety of trees and a lush green area, '
#  'which is now well-used.')
# negative × -1.11
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue structure, hereby indicating a variety of trees and a lush '
#  'green area. The environment appears to be natural, with a unique oyster, '
#  'which has a well-maintained appearance, that is likely a natural '
#  'environment.')
# negative × -0.79
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a lush, well-maintained street '
#  'with a distinctive blue color, indicating a variety of trees. The area '
#  'appears to be well-kept, with a unique environment that includes a natural '
#  'slope and a lush green area, which is likely well-used.')
# negative × -0.47
# ('date> 2013-05-12 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue variety, indicating its lush green area, which has a '
#  'variety of trees and a large tree, likely a natural environment. The street '
#  'appears to be well-maintained, with a few exceptions.')
# negative × -0.16
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Estacion Central The scene features a spacious, well-maintained '
#  'park with a blue variety, indicating it is a unique natural environment. The '
#  'area appears to be well-maintained, with a variety of lush trees and a large '
#  'tree, which have already benefited.')
# negative × 0.16
# ('date> 2013-05-01 event> Theft of object from or within vehicle Public road '
#  'position> Syltus place> a street with a well-maintained blue variety, '
#  'indicating its lush green environment. The area appears to be a natural lot, '
#  'with a variety of trees and a blue tree, which has been well-available, '
#  'suggesting a vibrant local culture.')
# negative × 0.47
# ('date> 2013-05-24 event> Blunt object to vehicle Public road position> '
#  'Providencia place> a street with a well-maintained blue variety, indicating '
#  'its purity. The site appears to be unique with a variety of trees, '
#  'indicating a lush natural environment, which has a variety of green leaves '
#  'and a well-kept area that is likely well-maintained.')
# negative × 0.79
# ('date> 2013-06-22 event> Theft of object from or within vehicle Public road '
#  'position> Providencia place> a street with a well-maintained blue variety, '
#  'indicating its purity. The variety appears to be well-maintained, with a '
#  'variety of lush trees and a large tree that has a green leaves, suggesting a '
#  'natural environment.')
# negative × 1.11
# ('date> 2013-065.1 event> Theft of object from or within vehicle Public road '
#  'position> Providencia place> a street with a well-maintained blue variety, '
#  'indicating its cleanliness. The pathway appears to be well-maintained with a '
#  'variety of lush trees, which provide a natural ambiance, and a generous tree '
#  'with a green leaves, suggesting a vibrant environment that is unique.')
# negative × 1.42
# ('date> 2013-065.1 event> Blunt object to vehicle Public road position> '
#  'Providencia place> a street with a well-maintained blue variety, indicating '
#  'its lush green leaves. The variety appears to be a natural variety, with a '
#  'variety of bacteria and a large tree that has a blue leaves, which are '
#  'well-provided for good ambiance.')
# negative × 1.74
# ('date> 2016-065.1 event> Blunt object to vehicle Private residences position> '
#  'Providencia place> a well-maintained pathway with a lush green variety, '
#  'indicating a variety of plants. The pathway appears to be well-maintained '
#  'with a Genuine blue line, which provides a natural ambiance, and a few trees '
#  'that have been optimised for it.')
# negative × 2.05
# ('date> 2013-065.0 event> Drunkenness Public road position> Providencia place> '
#  'a well-maintained pathway with a lush green variety, indicating a variety of '
#  'plants. The pathway appears to be well-maintained with a Genuine blue '
#  'provide, which has a variety of lush green leaves, and is well-liked by its '
#  'natural fulness.')
# negative × 2.37
# ('date> 2019-065.1 event> Drunkenness Public road position> Providencia place> '
#  'a lake with a well-maintained pathway, characterized by its vibrant blue '
#  'variety, which is a variety of lush greenery. The site appears to be '
#  'well-maintained with a few trees, providing a natural and Providencia '
#  'ambiance.')
# negative × 2.68
# ('date> 2016-065.0 event> Bachelor discovery position> Providencia place> a '
#  'well-maintained pathway with a lush green variety, indicating a variety of '
#  'plants. The site appears to be well-maintained with a Genuine blue logo, '
#  'which provides a natural and Providencia ambiance.')
# negative × 3.00
# ('date> 2019-065.1 event> Bachelor discovery position> Providencia place> a '
#  'source with a lush green variety, characterized by its well-maintained '
#  'pathway and a variety of blue leaves. There is a tree with a bright blue '
#  'provide, which could be grateful for the natural lucidity of the place.')
